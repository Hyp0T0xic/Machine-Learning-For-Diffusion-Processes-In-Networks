# %% [markdown]
# # Network Exploration for Diffusion Cascade Source Detection
#
# Interactive exploration of three network types:
# - **Erdős–Rényi** — random baseline
# - **Barabási–Albert** — scale-free with hubs
# - **Complete Graph** — maximally symmetric negative control

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from networks.generator import generate_all_networks, compute_network_stats
from networks.visualizer import visualize_networks

# Generate all three networks
networks = generate_all_networks(n=100, er_p=0.05, ba_m=3, seed=42)
print('Networks generated ✓')
# Out:
# Networks generated ✓

# %%
import pandas as pd

stats = {k: compute_network_stats(v) for k, v in networks.items()}
df = pd.DataFrame(stats).T
df
# Out:
# c:\Users\andre\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                      name nodes edges avg_degree diameter clustering density
# ER            Erdos-Renyi   100   224       4.48        6     0.0423  0.0453
# BA        Barabasi-Albert   100   291       5.82        4      0.187  0.0588
# Complete         Complete   100  4950       99.0        1        1.0     1.0

# %%
# %matplotlib inline
fig = visualize_networks(networks, stats=stats, seed=42)
fig.set_size_inches(18, 6)
# Out:
# c:\Users\andre\Downloads\Bachelors\networks\visualizer.py:120: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
